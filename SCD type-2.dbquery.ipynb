-- %%
create table customer(
  id INT,
  name STRING,
  city STRING,
  salary INT,
  isActive CHAR(1),
  startdate DATE,
  enddate DATE,
  modified_date TIMESTAMP
);

insert into customer values
--(1,'John','Berlin',500,'Y','2019-01-01',null,CURRENT_TIMESTAMP),
(2,'Jane','London',600,'Y','2019-01-01',null,CURRENT_TIMESTAMP
),
(3,'Mary','Paris',700 ,'Y','2019-01-01',null,CURRENT_TIMESTAMP
),
(4,'Mike','London',800,'N','2019-01-01','2024-08-01',CURRENT_TIMESTAMP
);


select * from customer;
